# %%
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
from datetime import datetime, timedelta
# %matplotlib inline

# %%
dir = '/srv/seolab/srai/observation/SatelliteVsBuoy/downloads/TRMM_data/downloaded/TRMM_nc_2000'
file = '/2A25.20000111.12218.7.nc'

# %%
ds = Dataset(dir + file)

# %%
Year = np.array(ds.variables['Year'])

Month = np.array(ds.variables['Month'])

DayOfMonth = np.array(ds.variables['DayOfMonth'])

Hour = np.array(ds.variables['Hour'])

Minute = np.array(ds.variables['Minute'])

Second = np.array(ds.variables['Second'])

MilliSecond = np.array(ds.variables['MilliSecond'])

DayOfYear = np.array(ds.variables['DayOfYear'])

scanTime_sec = np.array(ds.variables['scanTime_sec'])

# %%
ds.variables['Month']
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# int8 Month(nscan)
#     hdf_name: Month
#     units: months
# unlimited dimensions:
# current shape = (9140,)
# filling on, default _FillValue of -127 ignored

# %%
ds.variables['DayOfMonth']
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# int8 DayOfMonth(nscan)
#     hdf_name: DayOfMonth
#     units: days
# unlimited dimensions:
# current shape = (9140,)
# filling on, default _FillValue of -127 ignored

# %%
ds.variables['Hour']
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# int8 Hour(nscan)
#     hdf_name: Hour
#     units: hours
# unlimited dimensions:
# current shape = (9140,)
# filling on, default _FillValue of -127 ignored

# %%
ds.variables['Minute']
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# int8 Minute(nscan)
#     hdf_name: Minute
#     units: minutes
# unlimited dimensions:
# current shape = (9140,)
# filling on, default _FillValue of -127 ignored

# %%
ds.variables['Second']
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# int8 Second(nscan)
#     hdf_name: Second
#     units: s
# unlimited dimensions:
# current shape = (9140,)
# filling on, default _FillValue of -127 ignored

# %%
ds.variables['MilliSecond']
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# int16 MilliSecond(nscan)
#     hdf_name: MilliSecond
#     units: ms
# unlimited dimensions:
# current shape = (9140,)
# filling on, default _FillValue of -32767 used

# %%
ds.variables['DayOfYear']
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# int16 DayOfYear(nscan)
#     hdf_name: DayOfYear
#     units: days
# unlimited dimensions:
# current shape = (9140,)
# filling on, default _FillValue of -32767 used

# %%
ds.close()

# %%
xds = xr.open_dataset(dir+file)

# %%
xds
# Out:
# <xarray.Dataset>
# Dimensions:                  (nray: 49, fakeDim1: 3, nscan: 9140, fakeDim3: 3,
#                               fakeDim4: 3, ncell1: 80, ncell2: 5, fakeDim7: 7,
#                               fakeDim8: 2, fakeDim9: 2, nmeth: 2, fakeDim11: 3,
#                               fakeDim12: 3, nestmeth: 6, fakeDim14: 2)
# Dimensions without coordinates: nray, fakeDim1, nscan, fakeDim3, fakeDim4,
#                                 ncell1, ncell2, fakeDim7, fakeDim8, fakeDim9,
#                                 nmeth, fakeDim11, fakeDim12, nestmeth, fakeDim14
# Data variables: (12/81)
#     mainlobeEdge             (nray) int8 ...
#     sidelobeRange            (nray, fakeDim1) int8 ...
#     Year                     (nscan) int16 ...
#     Month                    (nscan) int8 ...
#     DayOfMonth               (nscan) timedelta64[ns] ...
#     Hour                     (nscan) timedelta64[ns] ...
#     ...                       ...
#     pia_srt                  (nscan, nray, nestmeth) float32 ...
#     stddev_srt               (nscan, nray, nestmeth) float32 ...
#     errorRain                (nscan, nray) float32 ...
#     errorZ                   (nscan, nray) float32 ...
#     spare                    (nscan, nray, fakeDim14) float32 ...
#     rainType                 (nscan, nray) int16 ...
# Attributes: (12/17)
#     SwathHeader:            NumberScansInSet=1;\nMaximumNumberScansTotal=1000...
#     Parameters_Errors:       01 0.7     d_Zm_typ       /* Typical error (offs...
#     Parameters_Other:         1  /* parameter file for v6.9 of 2A25. January ...
#     Parameters_Stratiform:    1  /* parameter file for v6.9 of 2A25. January ...
#     Parameters_Convective:    1  /* parameter file for v6.9 of 2A25. January ...
#     Parameters_General:       1  /* parameter file for v7.2 of 2A25. Aug. 21,...
#     ...                     ...
#     creation_date:          Thu 07 Mar 2024 01:23:06 PM EST
#     NCL_Version:            6.6.2
#     system:                 Linux kumo.admin.whoi.edu 5.15.0-97-generic #107-...
#     Conventions:            None
#     hdf_source:             2A25.20000111.12218.7.HDF
#     title:                  NCL: convert-HDF-to-netCDF

# %%
dateTimeArr = []
for i in range(len(Year)):
    dateTimeArr.append(datetime(Year[i],Month[i],DayOfMonth[i],Hour[i],Minute[i],Second[i],MilliSecond[i]))
dateTimeArr = np.array(dateTimeArr)

# %%
new_coords = {'Time': dateTimeArr}
xds = xds.rename({'nscan': 'Time'}).assign_coords(new_coords)

xds = xds.drop_vars(["Year",
                    "Month",
                    "DayOfMonth",
                    "Hour",
                    "Minute",
                    "Second",
                    "MilliSecond",
                    "DayOfYear",
                    "scanTime_sec"])
# Out:
# <xarray.Dataset>
# Dimensions:                  (nray: 49, fakeDim1: 3, Time: 9140, fakeDim3: 3,
#                               fakeDim4: 3, ncell1: 80, ncell2: 5, fakeDim7: 7,
#                               fakeDim8: 2, fakeDim9: 2, nmeth: 2, fakeDim11: 3,
#                               fakeDim12: 3, nestmeth: 6, fakeDim14: 2)
# Coordinates:
#   * Time                     (Time) datetime64[ns] 2000-01-11T15:46:51.000156...
# Dimensions without coordinates: nray, fakeDim1, fakeDim3, fakeDim4, ncell1,
#                                 ncell2, fakeDim7, fakeDim8, fakeDim9, nmeth,
#                                 fakeDim11, fakeDim12, nestmeth, fakeDim14
# Data variables: (12/72)
#     mainlobeEdge             (nray) int8 ...
#     sidelobeRange            (nray, fakeDim1) int8 ...
#     Latitude                 (Time, nray) float32 ...
#     Longitude                (Time, nray) float32 ...
#     missing                  (Time) int8 ...
#     validity                 (Time) int8 ...
#     ...                       ...
#     pia_srt                  (Time, nray, nestmeth) float32 ...
#     stddev_srt               (Time, nray, nestmeth) float32 ...
#     errorRain                (Time, nray) float32 ...
#     errorZ                   (Time, nray) float32 ...
#     spare                    (Time, nray, fakeDim14) float32 ...
#     rainType                 (Time, nray) int16 ...
# Attributes: (12/17)
#     SwathHeader:            NumberScansInSet=1;\nMaximumNumberScansTotal=1000...
#     Parameters_Errors:       01 0.7     d_Zm_typ       /* Typical error (offs...
#     Parameters_Other:         1  /* parameter file for v6.9 of 2A25. January ...
#     Parameters_Stratiform:    1  /* parameter file for v6.9 of 2A25. January ...
#     Parameters_Convective:    1  /* parameter file for v6.9 of 2A25. January ...
#     Parameters_General:       1  /* parameter file for v7.2 of 2A25. Aug. 21,...
#     ...                     ...
#     creation_date:          Thu 07 Mar 2024 01:23:06 PM EST
#     NCL_Version:            6.6.2
#     system:                 Linux kumo.admin.whoi.edu 5.15.0-97-generic #107-...
#     Conventions:            None
#     hdf_source:             2A25.20000111.12218.7.HDF
#     title:                  NCL: convert-HDF-to-netCDF

# %%
xds.to_netcdf('test.nc')
# Out:
# /tmp/ipykernel_1497759/3485659914.py:1: SerializationWarning: saving variable rain with floating point data as an integer dtype without any _FillValue to use for NaNs
#   xds.to_netcdf('test.nc')
# /tmp/ipykernel_1497759/3485659914.py:1: SerializationWarning: saving variable correctZFactor with floating point data as an integer dtype without any _FillValue to use for NaNs
#   xds.to_netcdf('test.nc')

# %%
ds = Dataset('test.nc')

# %%
ds.variables.keys()
# Out:
# dict_keys(['mainlobeEdge', 'sidelobeRange', 'Year', 'Month', 'DayOfMonth', 'Hour', 'Minute', 'Second', 'MilliSecond', 'DayOfYear', 'scanTime_sec', 'Latitude', 'Longitude', 'missing', 'validity', 'qac', 'geoQuality', 'dataQuality', 'SCorientation', 'acsMode', 'yawUpdateS', 'prMode', 'prStatus1', 'prStatus2', 'FractionalGranuleNumber', 'scPosX', 'scPosY', 'scPosZ', 'scVelX', 'scVelY', 'scVelZ', 'scLat', 'scLon', 'scAlt', 'scAttRoll', 'scAttPitch', 'scAttYaw', 'SensorOrientationMatrix', 'greenHourAng', 'scLocalZenith', 'rain', 'reliab', 'correctZFactor', 'attenParmAlpha', 'attenParmBeta', 'parmNode', 'precipWaterParmA', 'precipWaterParmB', 'ZRParmA', 'ZRParmB', 'zmmax', 'rainFlag', 'rangeBinNum', 'rainAve', 'precipWaterSum', 'epsilon_0', 'method', 'epsilon', 'epsilon_alpha', 'epsilon_nubf', 'zeta', 'zeta_mn', 'zeta_sd', 'sigmaZero', 'freezH', 'nubfCorrectFactor', 'stddev_zeta', 'stddev_PIAsrt', 'stddev_alpha', 'stddev_Zm', 'qualityFlag', 'nearSurfRain', 'nearSurfZ', 'e_SurfRain', 'pia', 'pia_srt', 'stddev_srt', 'errorRain', 'errorZ', 'spare', 'rainType', 'Time'])

# %%
ds.variables['Time']

# %%
ds.close()
