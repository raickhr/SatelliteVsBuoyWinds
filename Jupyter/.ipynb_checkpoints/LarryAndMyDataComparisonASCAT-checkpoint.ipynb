# %%
from netCDF4 import Dataset, date2num, num2date
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from glob import glob
# %matplotlib inline

# %%
lat = -8
lon = -125

if lat < 0:
    latUnit = 'S'
else:
    latUnit = 'N'

if lon < 0:
    lonUnit = 'W'
else:
    lonUnit = 'E'

lat = abs(lat)
lon = abs(lon)

myID = f'{lat:02d}{latUnit}_{lon:03d}{lonUnit}'
larrID = f'{lat}{latUnit.lower()}{lon}{lonUnit.lower()}'

myQSfile = f'../../downloads/Buoy/extractedGZ/WINDS/T_{myID}_matchup_2000.nc'
larryQSfile = f'../../downloads/larryNielData/larry2020/EXP11/fromLarry_{larrID}_data.nc'

mDS = Dataset(myQSfile)
lDS = Dataset(larryQSfile)

cdfTime = mDS.variables['time_QS']
timeUnit = cdfTime.units
timeArr = np.array(cdfTime)
cftimes=num2date(timeArr, timeUnit)
myTime = np.array([datetime(dtm.year, dtm.month, dtm.day, dtm.hour, dtm.minute, dtm.second) for dtm in cftimes])

cdfTime = mDS.variables['time_TAO']
timeUnit = cdfTime.units
timeArr = np.array(cdfTime)
cftimes=num2date(timeArr, timeUnit)
myTime_TAO = np.array([datetime(dtm.year, dtm.month, dtm.day, dtm.hour, dtm.minute, dtm.second) for dtm in cftimes])


exact = abs(myTime_TAO - myTime) < timedelta(seconds=1)

mWspd = np.array(mDS.variables['U10N_QS'])
mWdir = np.array(mDS.variables['U10N_dir_QS'])
print(np.max(mWdir), np.max(mWdir))
mask = np.logical_or(abs(mWspd) > 1000,abs(mWdir) == 0)
mWspd[mask] = float('nan')
mWdir[mask] = float('nan')

mWspd_TAO = np.array(mDS.variables['U10N_TAO'])
mWdir_TAO = (-np.array(mDS.variables['U10N_dir_TAO'])+450)%360
mWspd_TAO[abs(mWspd_TAO) > 1000] = float('nan')
mWdir_TAO[abs(mWspd_TAO) > 1000] = float('nan')



cdfTime = lDS.variables['time']
timeUnit = 'days since 0001-01-01 00:00:0.0'
timeArr = np.array(cdfTime)
cftimes=num2date(timeArr, timeUnit, has_year_zero=True)
larryTime = np.array([datetime(dtm.year, dtm.month, dtm.day, dtm.hour, dtm.minute, dtm.second) - timedelta(365) for dtm in cftimes])

lWspd = np.array(lDS.variables['sat_wspd10n'])
u = np.array(lDS.variables['sat_u10n'])
v = np.array(lDS.variables['sat_v10n'])
lWdir = np.rad2deg(np.arctan2(v,u))%360

lWspd_TAO = np.array(lDS.variables['buoy_wspd10n'])
u = np.array(lDS.variables['buoy_u10n'])
v = np.array(lDS.variables['buoy_v10n'])

lWdir_TAO = np.rad2deg(np.arctan2(v,u))%360
# Out:
# 358.2335510253906 358.2335510253906

# %%
np.sum(exact)

extTime = myTime[exact]
extQSWspd = mWspd[exact]
extTAOwsp = mWspd_TAO[exact]

extQSWdir = mWdir[exact]
extTAOdir = mWdir_TAO[exact]

# %%
fig, axes = plt.subplots(nrows=2, ncols =1, figsize = (20,8))

ax = axes[0]
ax.plot(myTime, mWspd, label='me')
ax.plot(larryTime, lWspd, label='larry', alpha = 0.8)
ax.set_title('QuikSCAT wind speed')
ax.legend()

ax = axes[1]
ax.plot(myTime, mWdir, label='me')
ax.plot(larryTime, (lWdir), label='larry', alpha = 0.8)
ax.legend()
ax.set_title('QuikSCAT wind dir')

plt.savefig(f'/images/QS_CompWithLarryMatchUp_{myID}.png', dpi=70)
# Out:
# Text(0.5, 1.0, 'QuikSCAT wind dir')

# %%
fig, axes = plt.subplots(nrows=2, ncols =1, figsize = (20,8))

ax = axes[0]
ax.plot(myTime, mWspd_TAO, label='me')
ax.plot(larryTime, lWspd, label='larry', alpha = 0.8)
ax.set_title('TAO wind speed')
ax.legend()

ax = axes[1]
ax.plot(myTime, mWdir_TAO, label='me')
ax.plot(larryTime, (lWdir), label='larry', alpha = 0.8)
ax.legend()
ax.set_title('TAO wind dir')

plt.savefig(f'/images/Buoy_CompWithLarryMatchUp_{myID}.png', dpi=70)
# Out:
# Text(0.5, 1.0, 'TAO wind dir')

# %%
d1 = datetime(2003,1,1)
start1 = np.argmin(abs(myTime-d1))
start2 = np.argmin(abs(larryTime-d1))

d2 = datetime(2005,1,1)
end1 = np.argmin(abs(myTime-d2))
end2 = np.argmin(abs(larryTime-d2))

plt.figure(figsize = (20,6))
plt.plot(myTime[start1:end1], mWspd[start1:end1], label='me')
plt.plot(larryTime[start2:end2], lWspd[start2:end2], label='larry')
plt.legend()
plt.title('QuikSCAT wind speed')

plt.figure(figsize = (20,6))
plt.plot(myTime[start1:end1], (mWdir[start1:end1]), label='me')
plt.plot(larryTime[start2:end2], (lWdir[start2:end2]), label='larry')
plt.legend()
plt.title('QuikSCAT wind direction')

plt.figure()
plt.scatter(extTime, extQSWdir, s=100, color = 'red', label='QS')
plt.scatter(extTime, extTAOdir, s=50, color = 'black', label='TAO')
plt.legend()

# %%
plt.figure(figsize = (20,6))
plt.plot(myTime, mWspd_TAO, label='me')
plt.plot(larryTime, lWspd_TAO, label='larry')
plt.title('TAO wind speed')
plt.legend()


plt.figure(figsize = (20,6))
plt.plot(myTime, mWdir_TAO, label='me')
plt.plot(larryTime, (lWdir_TAO), label='larry')
plt.title('TAO wind dir')

plt.legend()

plt.figure()
plt.scatter(extTime, extQSWspd, s=100, color = 'red', label='QS')
plt.scatter(extTime, extTAOwsp, s=50, color = 'black', label='TAO')
plt.legend()

# %%
d1 = datetime(2003,1,1)
start1 = np.argmin(abs(myTime-d1))
start2 = np.argmin(abs(larryTime-d1))

d2 = datetime(2005,1,1)
end1 = np.argmin(abs(myTime-d2))
end2 = np.argmin(abs(larryTime-d2))

plt.figure(figsize = (20,6))
plt.plot(myTime[start1:end1], mWspd_TAO[start1:end1], label='me')
plt.plot(larryTime[start2:end2], lWspd_TAO[start2:end2], label='larry')
plt.legend()
plt.title('TAO wind speed')

plt.figure(figsize = (20,6))
plt.plot(myTime[start1:end1], (mWdir_TAO[start1:end1]), label='me')
plt.plot(larryTime[start2:end2], (lWdir_TAO[start2:end2]), label='larry')
plt.legend()
plt.title('TAO wind dir')
# Out:
# Text(0.5, 1.0, 'TAO wind dir')

# %%
mQS_u10 = mWspd * np.cos(np.deg2rad())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 mQS_u10 = mWspd * np.cos(np.deg2rad())
#
# TypeError: deg2rad() takes from 1 to 2 positional arguments but 0 were given
