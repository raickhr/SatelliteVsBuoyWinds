# %%
from netCDF4 import Dataset, num2date, date2num
import matplotlib.pyplot as plt
import numpy as np

# %%
fname = '../../downloads/WaveReanalysis/all/T_0N_140W_wave_2000_01_01_T00.00.00_to_2012_12_31_T21.00.00.nc'

# %%
epsilon = 0.25
ds = Dataset(fname)

lat = np.array(ds.variables['lat'])
lon = np.array(ds.variables['lon'])%360
time = np.array(ds.variables['time'])

VTPK = np.array(ds.variables['VTPK'])

# %%
plt.plot(time[0:20], VTPK[0:20])
plt.plot(time[0:20], lat[0:20])
plt.plot(time[0:20], lon[0:20])

# %%
lat[0:5]
# Out:
# array([-7.4112938e-13, -7.4112938e-13, -7.4112938e-13, -7.4112938e-13,
#        -7.4112938e-13])

# %%
lon[0:5]
# Out:
# array([220., 220., 220., 220., 220.])

# %%
time[0:5]
# Out:
# array([438288., 438291., 438294., 438297., 438300.])

# %%
plt.plot(lon)

# %%
plt.plot(lat[3250:3500],time[3250:3500])

# %%
a=np.zeros((5), dtype=float)*float('nan')

# %%
a
# Out:
# array([nan, nan, nan, nan, nan])
