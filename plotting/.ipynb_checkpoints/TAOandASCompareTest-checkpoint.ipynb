# %%
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
lat = -2
lon = -155

if lat < 0:
    latUnits = 'S'
else:
    latUnits = 'N'

if lon < 0:
    lonUnits = 'W'
else:
    lonUnits = 'E'

lat=abs(lat)
lon=abs(lon)

ds = Dataset('../../downloads/Buoy/extractedGZ/WINDS/T_00N_095W_WINDS_2000.nc')
#ds = Dataset(f'../../downloads/Buoy/extractedGZ/WINDS/T_{lat:02d}{latUnits}_{lon:03d}{lonUnits}_matchupNearestFour_2000.nc')
ds.variables.keys()
# Out:
# dict_keys(['TIME', 'HEIGHT', 'LATITUDE', 'LONGITUDE', 'WDIR', 'WDIR_QC', 'WDIR_DM', 'WSPD', 'WSPD_QC', 'WSPD_DM', 'UWND', 'VWND'])

# %%
WSPD_QC  = np.array(ds.variables['WSPD_QC'])

# %%
plt.plot(WSPD_QC)

# %%
dist = np.array(ds.variables['dist'][:,:])
satWspd = np.array(ds.variables['U10N_QS'][0,:])
satWdir = np.array(ds.variables['U10N_dir_QS'][0,:])

taoWspd = np.array(ds.variables['U10N_TAO'][:])
taoWdir = np.array(ds.variables['U10N_dir_TAO'][:])

satLat = np.array(ds.variables['satLat'][:,:])
satLon = np.array(ds.variables['satLon'][:,:])
satTimeDiff = np.array(ds.variables['satTimeDiff'][:,:])
ds.close()

# %%
np.nanmin(dist), np.nanmax(dist), np.nanmin(satTimeDiff), np.nanmax(satTimeDiff)
# Out:
# (0.09987846330926588, 15.531773342447517, -599.0, 599.0)

# %%
plt.plot(dist[0,:])

# %%
minDist = dist[0,:]
#minDist = minDist[~np.isnan(minDist)]

# %%
plt.figure(figsize=(20,3))
plt.plot(minDist)

# %%
timeDiff = satTimeDiff[0,:]
#timeDiff = timeDiff[~np.isnan(timeDiff)]

# %%
plt.figure(figsize=(20,3))
plt.plot(timeDiff)

# %%
exactTime = abs(timeDiff) < 1
plt.plot(minDist[exactTime])
np.sum(exactTime)
# Out:
# 9

# %%
plt.figure(figsize=(20,3))
#mask = abs(satWspd)<100 
#mask *= abs(taoWspd)<100
plt.plot(taoWspd, label='TAO')
plt.plot(satWspd, label='QS')
plt.legend()

# %%
plt.figure(figsize=(20,3))
# mask = abs(satWspd)<100 
# mask *= abs(taoWspd)<100
plt.plot(taoWdir, label='TAO')
plt.plot(satWdir, label='QS')
plt.legend()

# %%
plt.figure(figsize=(20,3))
plt.plot(taoWdir-satWdir, label='TAO')
plt.ylim(-25,25)
plt.legend()

# %%
plt.figure(figsize=(20,3))
plt.plot(taoWspd-satWspd, label='TAO')
plt.ylim(-2,2)
plt.legend()

# %%
len(taoWspd[mask])
# Out:
# 5589
