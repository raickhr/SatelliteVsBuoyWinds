# %%
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import xarray as xr
from netCDF4 import Dataset, num2date, date2num
from datetime import datetime, timedelta
import os


def plotTimeSeriesByClusterLabel(df, lat, lon, ax1, ax2, cluster_label=0, color='blue'):
    try:
        subDF = df.loc[df['lat'] == lat]
        subDF = subDF.loc[subDF['lon'] == lon%360]
        subDF = subDF.loc[subDF['label'] == cluster_label]
    except:
        return

    if len(subDF) < 1:
        return

    if lat < 0:
        lat = abs(lat)
        latUnits = 'S'
    else:
        latUnits = 'N'

    if lon < 0:
        lonUnits = 'W'
        lon = abs(lon) # 360
    else:
        lonUnits = 'E'

    deployFileName = f'../../downloads/Buoy/extractedGZ/WINDS/T_{lat:02d}{latUnits}_{lon:03d}{lonUnits}/T_{lat:02d}{latUnits}_{lon:03d}{lonUnits}_DeploymentDates.nc'
        
    if os.path.isfile(deployFileName):
        ds2 = Dataset(deployFileName)
        startDates = np.array(ds2.variables['startDate'])
        units = ds2.variables['startDate'].units
        cftimes = num2date(startDates, units)
        startDates = np.array([datetime(dtm.year, dtm.month, dtm.day, dtm.hour, dtm.minute, dtm.second) for dtm in cftimes])

        endDates = np.array(ds2.variables['endDate'])
        units = ds2.variables['endDate'].units
        cftimes = num2date(endDates, units)
        endDates = np.array([datetime(dtm.year, dtm.month, dtm.day, dtm.hour, dtm.minute, dtm.second) for dtm in cftimes])
        ds2.close()
        
        cftimes = num2date(subDF['time'], 'seconds since 1990-01-01 00:00:00')
        dates = np.array([datetime(dtm.year, dtm.month, dtm.day, dtm.hour, dtm.minute) for dtm in cftimes])
        y1 = subDF['speedDiff']
        y2 = subDF['directionDiff']

        for i in range(len(startDates)):
            colorR =list(np.random.choice(range(256), size=3)/256)
            
            ax1.axvspan(startDates[i], endDates[i], 
                    alpha=0.05, color=colorR)
            ax2.axvspan(startDates[i], endDates[i], 
                    alpha=0.05, color=colorR)
        
        #ax1.scatter(subDF['time'], y1, s=2, label = cluster_label)#, c = subDF['label'])
        #ax2.scatter(subDF['time'], y2, s=2, label = cluster_label)#, c = subDF['label'])

        ax1.scatter(dates, y1, s=3, label = cluster_label, c = color)
        ax2.scatter(dates, y2, s=3, label = cluster_label, c = color)
        ax1.set_title(f'{lat:02d}{latUnits} {lon:03d}{lonUnits} speed Diff')
        ax2.set_title(f'{lat:02d}{latUnits} {lon:03d}{lonUnits} direction Diff')


latList = [-9, -8, -5, -2, 0, 2, 5, 8, 9]
lonList = [-95, -110, -125, -140, -155, -170, -180, 165]

ylen = len(latList)
xlen = len(lonList)

taskList = []

for latId  in range(ylen):
    for lonId in range(xlen):
        taskList.append([latList[latId], lonList[lonId]])

ntasks = len(taskList)

i = 0
tlen = 0

metaData = np.empty((0,19), dtype=float)
metaDataIndex = ['time',
                 'lat', 
                 'lon',
                 'U10N_QS',
                 'U10N_dir_QS',
                 'satTimeDiff',
                 'dist',
                 'satLon',
                 'satLat',
                 'U10N_TAO',
                 'U10N_dir_TAO',
                 'U10N_TAO2',
                 'U10N_dir_TAO2',
                 'U10N_x_TAO2',
                 'U10N_y_TAO2',
                 'SST_TAO',
                 'RH_TAO',
                 'AIRT_TAO',
                 'Deployment Classifier']

for task in taskList:
    lat = task[0]
    lon = task[1]

    LAT = lat
    LON = lon

    if lat < 0:
        latUnits = 'S'
    else:
        latUnits = 'N'

    if lon < 0:
        lonUnits = 'W'
        LON += 360
    else:
        lonUnits = 'E'
    
    lat=abs(lat)
    lon=abs(lon)

    matchFname = f'../../downloads/Buoy/extractedGZ/WINDS/T_{lat:02d}{latUnits}_{lon:03d}{lonUnits}_matchupNearestFour_2000.nc'
    deployFileName = f'../../downloads/Buoy/extractedGZ/WINDS/T_{lat:02d}{latUnits}_{lon:03d}{lonUnits}/T_{lat:02d}{latUnits}_{lon:03d}{lonUnits}_DeploymentDates.nc'
    
    if os.path.isfile(matchFname):

        ds = Dataset(matchFname)
        arr = np.empty((0,1), dtype=float)
        for i in range(3,18):
            if i <= 8:
                #print(i, metaDataIndex[i])
                readArr = np.array([ds.variables[metaDataIndex[i]][0,:]]).T
                #print(readArr.shape)
                #print(arr.shape)
                if len(arr) == 0:
                    arr = np.concatenate((arr, readArr), axis = 0)
                else:
                    arr = np.concatenate((arr, readArr), axis = 1)
            else:
                #print(i, metaDataIndex[i])
                readArr = np.array([ds.variables[metaDataIndex[i]][:]]).T
                #print(readArr.shape)
                #print(arr.shape)
                arr = np.concatenate((arr, readArr), axis = 1)

        latArr = np.array([len(arr)*[LAT]]).T
        lonArr = np.array([len(arr)*[LON]]).T
        timeArr = np.array(ds.variables['time'])

        # latArr = latArr[:,np.newaxis]
        # lonArr = lonArr[:,np.newaxis]
        timeArr = timeArr[:,np.newaxis]
        
        #print('lonArr', lonArr.shape)
        arr = np.concatenate((lonArr, arr), axis=1)

        #print('latArr', latArr.shape)
        arr = np.concatenate((latArr, arr), axis=1)

        #print('timeArr', timeArr.shape)
        arr = np.concatenate((timeArr, arr), axis=1)

        ds2 = Dataset(deployFileName)
        startDates = np.array(ds2.variables['startDate'])
        endDates = np.array(ds2.variables['endDate'])

        depNum = np.zeros((len(arr),1), dtype=int)
        c = 1
        for i in range(1,len(startDates)):
            mask = timeArr >= startDates[i]
            mask *= timeArr <= endDates[i]
            depNum[mask] = c
            c = c+1

        arr = np.concatenate((arr, depNum), axis=1)


        metaData = np.concatenate((metaData, arr), axis=0)
        #ds = ds.expand_dims('lat', axis= 0)
        

nanVals = np.sum(metaData, axis=1)
mask = np.isnan(nanVals)
print('MetaData.shape', metaData.shape, 'masked rows', np.sum(mask))
metaData = metaData[~mask, :]
print('new MetaData.shape', metaData.shape)


df = pd.DataFrame(metaData, columns = metaDataIndex )
df['speedDiff'] = df['U10N_QS'] - df['U10N_TAO']
df['absSpeedDiff'] = abs(df['U10N_QS'] - df['U10N_TAO'])

dDiff = (df['U10N_dir_QS'] - df['U10N_dir_TAO'])%360
dDiff[dDiff > 180] -= 360 #- dDiff[dDiff > 180] 
dDiff[dDiff < -180] += 360
df['directionDiff'] = dDiff
df['absDirectionDiff'] = abs(dDiff)


selectX = [#'time',
           'U10N_QS',
           'U10N_dir_QS',
           'satTimeDiff',
           'dist',
           'U10N_TAO',
           'U10N_dir_TAO',
           'U10N_x_TAO2',
           'U10N_y_TAO2',
           'SST_TAO',
           'RH_TAO',
           'AIRT_TAO',
           #'speedDiff',
           #'directionDiff',
           'absSpeedDiff',
           'absDirectionDiff']

X = df[selectX]

normX = (X - X.mean(axis=0))/ X.std(axis=0)

kmeans = KMeans(n_clusters=3, random_state=0, n_init="auto", max_iter = 10000).fit(normX)
df['label'] = kmeans.labels_

del X, normX

latList = [-9, -8, -5, -2, 0, 2, 5, 8, 9]
lonList = [-95, -110, -125, -140, -155, -170, -180, 165]

#latList = [-5]
#lonList = [-110]

ylen = len(latList)
xlen = len(lonList)

taskList = []

for latId  in range(ylen):
    for lonId in range(xlen):
        taskList.append([latList[latId], lonList[lonId]])

ntasks = len(taskList)
# Out:
# MetaData.shape (199639, 19) masked rows 7925
# new MetaData.shape (191714, 19)

# %%
for task in taskList:
    LAT = task[0]
    LON = task[1]
    lat = LAT
    lon = LON

    if lat < 0:
        lat = abs(lat)
        latUnits = 'S'
    else:
        latUnits = 'N'

    if lon < 0:
        lonUnits = 'W'
        lon = abs(lon) # 360
    else:
        lonUnits = 'E'

    deployFileName = f'../../downloads/Buoy/extractedGZ/WINDS/T_{lat:02d}{latUnits}_{lon:03d}{lonUnits}/T_{lat:02d}{latUnits}_{lon:03d}{lonUnits}_DeploymentDates.nc'
    matchFname = f'../../downloads/Buoy/extractedGZ/WINDS/T_{lat:02d}{latUnits}_{lon:03d}{lonUnits}_matchupNearestFour_2000.nc'
        
    if os.path.isfile(matchFname):
        try:
            print(LAT, LON)
            fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(20,8))
            print('ok1')
            plotTimeSeriesByClusterLabel(df, LAT, LON, axes[0], axes[1], cluster_label=0, color = 'blue')
            print('ok2')
            plotTimeSeriesByClusterLabel(df, LAT, LON, axes[0], axes[1], cluster_label=1, color = 'green')
            print('ok3')
            plotTimeSeriesByClusterLabel(df, LAT, LON, axes[0], axes[1], cluster_label=2, color = 'red')
            print('ok4')
            axes[0].set_ylabel('speed diff.')
            axes[0].legend()

            axes[1].set_ylabel('direction diff.')print(f'cluster :{cluster_label}', LAT, LON, deployFileName)
            axes[1].legend()
            
            fname = f'images/T_{lat:02d}{latUnits}_{lon:03d}{lonUnits}_Clustering.png'
            plt.savefig(fname, dpi=100)
            print(fname, deployFileName)
            plt.close()
        except:
            print('skipping ',deployFileName)
# Out:
# -8 -95
# ok1
# ok2
# ok3
# ok4
# images/T_08S_095W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_08S_095W/T_08S_095W_DeploymentDates.nc
# -8 -110
# ok1
# ok2
# ok3
# ok4
# images/T_08S_110W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_08S_110W/T_08S_110W_DeploymentDates.nc
# -8 -125
# ok1
# ok2
# ok3
# ok4
# images/T_08S_125W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_08S_125W/T_08S_125W_DeploymentDates.nc
# -8 -155
# ok1
# ok2
# ok3
# ok4
# images/T_08S_155W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_08S_155W/T_08S_155W_DeploymentDates.nc
# -8 -170
# ok1
# ok2
# ok3
# ok4
# images/T_08S_170W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_08S_170W/T_08S_170W_DeploymentDates.nc
# -8 165
# ok1
# ok2
# ok3
# ok4
# images/T_08S_165E_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_08S_165E/T_08S_165E_DeploymentDates.nc
# -5 -95
# ok1
# ok2
# ok3
# ok4
# images/T_05S_095W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_05S_095W/T_05S_095W_DeploymentDates.nc
# -5 -110
# ok1
# ok2
# ok3
# ok4
# images/T_05S_110W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_05S_110W/T_05S_110W_DeploymentDates.nc
# -5 -125
# ok1
# ok2
# ok3
# ok4
# images/T_05S_125W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_05S_125W/T_05S_125W_DeploymentDates.nc
# -5 -140
# ok1
# ok2
# ok3
# ok4
# images/T_05S_140W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_05S_140W/T_05S_140W_DeploymentDates.nc
# -5 -155
# ok1
# ok2
# ok3
# ok4
# images/T_05S_155W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_05S_155W/T_05S_155W_DeploymentDates.nc
# -5 -170
# ok1
# ok2
# ok3
# ok4
# images/T_05S_170W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_05S_170W/T_05S_170W_DeploymentDates.nc
# -5 165
# ok1
# ok2
# ok3
# ok4
# images/T_05S_165E_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_05S_165E/T_05S_165E_DeploymentDates.nc
# -2 -95
# ok1
# ok2
# ok3
# ok4
# images/T_02S_095W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_02S_095W/T_02S_095W_DeploymentDates.nc
# -2 -110
# ok1
# ok2
# ok3
# ok4
# images/T_02S_110W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_02S_110W/T_02S_110W_DeploymentDates.nc
# -2 -125
# ok1
# ok2
# ok3
# ok4
# images/T_02S_125W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_02S_125W/T_02S_125W_DeploymentDates.nc
# -2 -140
# ok1
# ok2
# ok3
# ok4
# images/T_02S_140W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_02S_140W/T_02S_140W_DeploymentDates.nc
# -2 -155
# ok1
# ok2
# ok3
# ok4
# images/T_02S_155W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_02S_155W/T_02S_155W_DeploymentDates.nc
# -2 -170
# ok1
# ok2
# ok3
# ok4
# images/T_02S_170W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_02S_170W/T_02S_170W_DeploymentDates.nc
# -2 -180
# ok1
# ok2
# ok3
# ok4
# images/T_02S_180W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_02S_180W/T_02S_180W_DeploymentDates.nc
# -2 165
# ok1
# ok2
# ok3
# ok4
# images/T_02S_165E_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_02S_165E/T_02S_165E_DeploymentDates.nc
# 0 -95
# ok1
# ok2
# ok3
# ok4
# images/T_00N_095W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_00N_095W/T_00N_095W_DeploymentDates.nc
# 0 -110
# ok1
# ok2
# ok3
# ok4
# images/T_00N_110W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_00N_110W/T_00N_110W_DeploymentDates.nc
# 0 -125
# ok1
# ok2
# ok3
# ok4
# images/T_00N_125W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_00N_125W/T_00N_125W_DeploymentDates.nc
# 0 -140
# ok1
# ok2
# ok3
# ok4
# images/T_00N_140W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_00N_140W/T_00N_140W_DeploymentDates.nc
# 0 -155
# ok1
# ok2
# ok3
# ok4
# images/T_00N_155W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_00N_155W/T_00N_155W_DeploymentDates.nc
# 0 -170
# ok1
# ok2
# ok3
# ok4
# images/T_00N_170W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_00N_170W/T_00N_170W_DeploymentDates.nc
# 0 -180
# ok1
# ok2
# ok3
# ok4
# images/T_00N_180W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_00N_180W/T_00N_180W_DeploymentDates.nc
# 0 165
# ok1
# ok2
# ok3
# ok4
# images/T_00N_165E_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_00N_165E/T_00N_165E_DeploymentDates.nc
# 2 -95
# ok1
# ok2
# ok3
# ok4
# images/T_02N_095W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_02N_095W/T_02N_095W_DeploymentDates.nc
# 2 -110
# ok1
# ok2
# ok3
# ok4
# images/T_02N_110W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_02N_110W/T_02N_110W_DeploymentDates.nc
# 2 -125
# ok1
# ok2
# ok3
# ok4
# images/T_02N_125W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_02N_125W/T_02N_125W_DeploymentDates.nc
# 2 -140
# ok1
# ok2
# ok3
# ok4
# images/T_02N_140W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_02N_140W/T_02N_140W_DeploymentDates.nc
# 2 -155
# ok1
# ok2
# ok3
# ok4
# images/T_02N_155W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_02N_155W/T_02N_155W_DeploymentDates.nc
# 2 -170
# ok1
# ok2
# ok3
# ok4
# images/T_02N_170W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_02N_170W/T_02N_170W_DeploymentDates.nc
# 2 -180
# ok1
# ok2
# ok3
# ok4
# images/T_02N_180W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_02N_180W/T_02N_180W_DeploymentDates.nc
# 2 165
# ok1
# ok2
# ok3
# ok4
# images/T_02N_165E_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_02N_165E/T_02N_165E_DeploymentDates.nc
# 5 -95
# ok1
# ok2
# ok3
# ok4
# images/T_05N_095W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_05N_095W/T_05N_095W_DeploymentDates.nc
# 5 -110
# ok1
# ok2
# ok3
# ok4
# images/T_05N_110W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_05N_110W/T_05N_110W_DeploymentDates.nc
# 5 -125
# ok1
# ok2
# ok3
# ok4
# images/T_05N_125W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_05N_125W/T_05N_125W_DeploymentDates.nc
# 5 -140
# ok1
# ok2
# ok3
# ok4
# images/T_05N_140W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_05N_140W/T_05N_140W_DeploymentDates.nc
# 5 -155
# ok1
# ok2
# ok3
# ok4
# images/T_05N_155W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_05N_155W/T_05N_155W_DeploymentDates.nc
# 5 -170
# ok1
# ok2
# ok3
# ok4
# images/T_05N_170W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_05N_170W/T_05N_170W_DeploymentDates.nc
# 5 165
# ok1
# ok2
# ok3
# ok4
# images/T_05N_165E_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_05N_165E/T_05N_165E_DeploymentDates.nc
# 8 -95
# ok1
# ok2
# ok3
# ok4
# images/T_08N_095W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_08N_095W/T_08N_095W_DeploymentDates.nc
# 8 -110
# ok1
# ok2
# ok3
# ok4
# images/T_08N_110W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_08N_110W/T_08N_110W_DeploymentDates.nc
# 8 -155
# ok1
# ok2
# ok3
# ok4
# images/T_08N_155W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_08N_155W/T_08N_155W_DeploymentDates.nc
# 8 -170
# ok1
# ok2
# ok3
# ok4
# images/T_08N_170W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_08N_170W/T_08N_170W_DeploymentDates.nc
# 8 -180
# ok1
# ok2
# ok3
# ok4
# images/T_08N_180W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_08N_180W/T_08N_180W_DeploymentDates.nc
# 8 165
# ok1
# ok2
# ok3
# ok4
# images/T_08N_165E_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_08N_165E/T_08N_165E_DeploymentDates.nc
# 9 -140
# ok1
# ok2
# ok3
# ok4
# images/T_09N_140W_Clustering.png ../../downloads/Buoy/extractedGZ/WINDS/T_09N_140W/T_09N_140W_DeploymentDates.nc
