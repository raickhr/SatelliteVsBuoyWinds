# %%
import xarray as xr
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ds = xr.open_dataset('/srv/data2/srai_poseidon/srai_poseidon/observation/SatelliteVsBuoy/downloads/QS_data/TAOpos_008S_110W/TAOpos_008S_110W_QS.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                           (time: 6643, cross_track: 3,
#                                        ambiguities: 4)
# Coordinates:
#   * time                              (time) datetime64[ns] 2000-01-01T13:08:...
#   * cross_track                       (cross_track) int64 0 1 2
#   * ambiguities                       (ambiguities) int64 0 1 2 3
# Data variables: (12/21)
#     retrieved_wind_speed              (time, cross_track) float64 ...
#     retrieved_wind_direction          (time, cross_track) float64 ...
#     rain_impact                       (time, cross_track) float64 ...
#     flags                             (time, cross_track) float64 ...
#     eflags                            (time, cross_track) float64 ...
#     nudge_wind_speed                  (time, cross_track) float64 ...
#     ...                                ...
#     number_in_aft                     (time, cross_track) float64 ...
# ...

# %%
time = ds['time']

# %%
plt.plot(time)
